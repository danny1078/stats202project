# %%
StudyA = read.csv('./data/Study_A.csv')
StudyB = read.csv('./data/Study_B.csv')
StudyC = read.csv('./data/Study_C.csv')
StudyD = read.csv('./data/Study_D.csv')
StudyE = read.csv('./data/Study_E.csv')
StudyE$LeadStatus = NA
AllStudies = rbind(StudyA, StudyB, StudyC, StudyD, StudyE)
StudyA$TxGroupDummy = StudyA$TxGroup == "Treatment"
StudyB$TxGroupDummy = StudyB$TxGroup == "Treatment"
StudyC$TxGroupDummy = StudyC$TxGroup == "Treatment"
StudyD$TxGroupDummy = StudyD$TxGroup == "Treatment"
StudyE$TxGroupDummy = StudyE$TxGroup == "Treatment"

# %%
HypTest <- function(data){
    Pvalues <- numeric()
    Test <- character()
    StudyName <- character()
    for(study in data){
        for(i in 1:7){
            PosTest <- lm(study[,8+i] ~ VisitDay + VisitDay:TxGroupDummy, data = study)
            Test <- c(Test, paste("P", i))
            Pvalues<- c(Pvalues,c(summary(PosTest)$coefficients[3,4]))
            StudyName <- c(StudyName,as.character(study[1,1]))
        }
        for(i in 1:7){
            NegTest <- lm(study[,15+i] ~ VisitDay + VisitDay:TxGroupDummy, data = study)
            Test <- c(Test, paste("N", i))
            # print(summary(NegTest)$coefficients[3,4])
            Pvalues<- c(Pvalues,summary(NegTest)$coefficients[3,4])
            StudyName <- c(StudyName,as.character(study[1,1]))
        }
        for(i in 1:16){
            GeneralTest <- lm(study[,22+i] ~ VisitDay + VisitDay:TxGroupDummy, data = study)
            Test <- c(Test, paste("G", i))
             #print(summary(GeneralTest)$coefficients[3,4])
            Pvalues<- c(Pvalues,summary(GeneralTest)$coefficients[3,4])
            StudyName <- c(StudyName,as.character(study[1,1]))
        }
    }
    return(data.frame(t(rbind(StudyName,Test,Pvalues))))
    
}

# %%
data = list(StudyA, StudyB, StudyC, StudyD, StudyE)

HypTestResults <- HypTest(data)
#HypTestResults
AResults <- HypTestResults[HypTestResults$StudyName == "A",]
BResults <- HypTestResults[HypTestResults$StudyName == "B",]
CResults <- HypTestResults[HypTestResults$StudyName == "C",]
DResults <- HypTestResults[HypTestResults$StudyName == "D",]
EResults <- HypTestResults[HypTestResults$StudyName == "E",]
Pvalues <- c(as.vector(AResults[,3]), as.vector(BResults[,3]), as.vector(CResults[,3]), as.vector(DResults[,3]), as.vector(EResults[,3]))
StudyNames <-c("A", "B", "C", "D", "E")
Tests <-c(as.vector(AResults$Test))
ResultsMatrix <- matrix(Pvalues, nrow = 5, ncol = 30, byrow = TRUE)
dimnames(ResultsMatrix) = list(StudyNames, Tests)
ResultsMatrix
# Out:
#   P 1                P 2                  P 3
# A 0.268544234817744  8.03905323406451e-06 1.19968996899355e-05
# B 0.180851679017597  0.0293648330363333   0.0618683607442855
# C 0.871911266728934  0.0819013586977574   0.0859350744872376
# D 0.0158261351294217 0.0247939282977415   0.0646080470296006
# E 0.194246994893289  0.0566550980525108   0.675040452309358
#   P 4                P 5                 P 6
# A 0.130201743033475  0.00203081893273092 0.730051175964909
# B 0.711681550432167  0.540921757148188   0.00342513180024175
# C 0.773256713181361  0.745972101075584   0.0210933470112304
# D 0.0191726176470775 0.386093633856546   0.000300091486911978
# E 0.714156252539366  0.19783183497036    0.146606265472815
#   P 7                  N 1                N 2                N 3
# A 0.202468507250776    0.0560347362602943 0.228710531699295  0.613396192361134
# B 0.190499391209312    0.0921304552862924 0.0718892356113756 0.293165080503445
# C 0.0249457477706512   0.0215388654213341 0.14566359270259   0.424044219731652
# D 0.000561935150591269 0.26390078670948   0.408702072802674  0.230236118698967
# E 0.00926710776197265  0.645946798877488  0.978733330117537  0.165917251187884
#   ... G 7               G 8                  G 9
# A ... 0.631731460631668 0.934725970653997    0.000998977911740808
# B ... 0.018467023394895 0.630969119062351    0.789322054150221
# C ... 0.414236319541187 0.12387830497212     0.625653979793014
# D ... 0.096678967160222 0.000178388514504991 0.144989250254276
# E ... 0.301454710049256 0.338649762576761    0.094203644438449
#   G 10              G 11                 G 12                G 13
# A 0.790362865056614 0.0687961375749993   0.157873869700371   0.242949012627613
# B 0.493915054480813 0.329022169691305    0.00202470064953686 0.109115619112578
# C 0.191291486709811 0.817811250569273    0.486949543766314   0.0275559965873459
# D 0.305532820930457 0.000296272998755667 0.0620212858402979  0.724632400027035
# E 0.640252662389889 0.581678899274538    0.25088528119898    0.122724755549757
#   G 14                 G 15               G 16
# A 0.0269811002014233   0.0575406064964853 0.142795753380997
# B 0.0372765269016059   0.0232207536504459 0.869643472103269
# C 0.00914757376859928  0.823337776517268  0.0233048613006126
# D 0.000870274974999083 0.150621275079532  0.248988951160801
# E 0.359576157964908    0.0795106006090916 0.311049677880158

# %%
write.csv(x = ResultsMatrix, file = "HypTest.csv")

# %%
# Out:
# character(0)
